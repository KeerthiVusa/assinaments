# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Histgrom

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
car_crashes=sns.load_dataset('car_crashes')

# %%
car_crashes
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm")

# %%
sns.displot(car_crashes,x='total',bin=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.displot(car_crashes,x='total',bin=10)
#
# File ~\anaconda3\lib\site-packages\seaborn\distributions.py:2210, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2207 if p.univariate:
#    2209     _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2210     p.plot_univariate_histogram(**hist_kws)
#    2212 else:
#    2214     _assign_default_kwargs(hist_kws, p.plot_bivariate_histogram, histplot)
#
# ...

# %%
car_crashes
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
car_crashes.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
syntax: histplot(data,x,y)

# %%
sns.histplot(car_crashes,x='total')
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %%
sns.histplot(car_crashes,y='total')
# Out:
# <Axes: xlabel='Count', ylabel='total'>

# %%
sns.histplot(car_crashes,x='total',binwidth=5
            )
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %%
sns.histplot(car_crashes,x='total',bins=10)
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %%
sns.histplot(car_crashes,x='total',kde=True)
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %%
# show histgrom on each category wise

# %%
car_crashes.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
# convert to logs
planets = sns.load_dataset("planets")
sns.histplot(data=planets, x="distance")
# Out:
# <Axes: xlabel='distance', ylabel='Count'>

# %%
sns.histplot(data=planets, x="distance", log_scale=True)
# Out:
# <Axes: xlabel='distance', ylabel='Count'>

# %% [markdown]
# # kdeplot

# %%
tips = sns.load_dataset("tips")
sns.kdeplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(tips,y='total_bill')
# Out:
# <Axes: xlabel='Density', ylabel='total_bill'>

# %%
sns.kdeplot(tips)
# Out:
# <Axes: ylabel='Density'>

# %%
# category wise

# %%
sns.kdeplot(data=tips, x="total_bill", hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=tips, x="total_bill", hue="time", multiple="stack")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # jointplot

# %%
# join plot

# %%
penguins = sns.load_dataset("penguins")
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")

# %%
# category wise

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")

# %% [markdown]
# # pair plot

# %%
penguins = sns.load_dataset("penguins")
sns.pairplot(penguins)

# %%
# category wise

# %%
sns.pairplot(penguins, hue="species")

# %%
# diagnal things as histogram

# %%
sns.pairplot(penguins, hue="species", diag_kind="hist")

# %% [markdown]
# # scatterplot

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# category wise

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# change style
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time", style="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# focusing on requiring points

# %%
sns.scatterplot(
    data=tips, x="total_bill", y="tip", hue="size", size="size",
    sizes=(20, 200), legend="full"
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Count plot

# %%
titanic= sns.load_dataset('titanic')

# %%
sns.countplot(titanic, x="class")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
# category wise

# %%
sns.countplot(titanic, x="class", hue="survived")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
# changing value to percent
sns.countplot(titanic, x="class", hue="survived", stat="percent")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 2
#       1 # changing value to percent
# ----> 2 sns.countplot(titanic, x="class", hue="survived", stat="percent")
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# -> 1586     self.draw_bars(ax, bar_kws)
#    1587     self.annotate_axes(ax)
#    1588     if self.orient == "h":
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:1569, in _BarPlotter.draw_bars(self, ax, kws)
# ...

# %% [markdown]
# # heatmap

# %%
glue = sns.load_dataset("glue").pivot(index="Model", columns="Task", values="Score")
sns.heatmap(glue)
# Out:
# <Axes: xlabel='Task', ylabel='Model'>

# %%
glue
# Out:
# Task         CoLA  MNLI  MRPC  QNLI   QQP   RTE  SST-2  STS-B
# Model
# BERT         60.5  86.7  89.3  92.7  72.1  70.1   94.9   87.6
# BiLSTM       11.6  65.6  81.8  74.6  62.5  57.4   82.8   70.3
# BiLSTM+Attn  18.6  67.6  83.9  74.3  60.1  58.4   83.0   72.8
# BiLSTM+CoVe  18.5  65.4  78.7  70.8  60.6  52.7   81.9   64.4
# BiLSTM+ELMo  32.1  67.2  84.7  75.5  61.1  57.4   89.3   70.3
# ERNIE        75.5  92.3  93.9  97.3  75.2  92.6   97.8   93.0
# RoBERTa      67.8  90.8  92.3  95.4  74.3  88.2   96.7   92.2
# T5           71.6  92.2  92.8  96.9  75.1  92.8   97.5   93.1

# %%
sns.heatmap(glue, annot=True)
# Out:
# <Axes: xlabel='Task', ylabel='Model'>

# %%
# generating ranks
sns.heatmap(glue, annot=glue.rank(axis="columns"))
# Out:
# <Axes: xlabel='Task', ylabel='Model'>

# %%
# select different name
sns.heatmap(glue, cmap="crest")
# Out:
# <Axes: xlabel='Task', ylabel='Model'>
